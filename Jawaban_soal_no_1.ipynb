# %%
import socket
import threading

HOST = "127.0.0.1"
PORT = 5050

def echo_server():
    server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server.bind((HOST, PORT))
    server.listen(1)
    print("[SERVER] Running on port", PORT)

    conn, addr = server.accept()
    print("[SERVER] Connected by", addr)
    data = conn.recv(1024).decode()
    print("[SERVER] Received:", data)

    conn.send(data.encode())

    conn.close()
    server.close()

# Jalankan server di thread terpisah
threading.Thread(target=echo_server, daemon=True).start()
# Out:
# [SERVER] Running on port 5050

# %%
import socket

HOST = "127.0.0.1"
PORT = 5050

client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client.connect((HOST, PORT))

pesan = "Tes Koneksi"
client.send(pesan.encode())

balikan = client.recv(1024).decode()

print("Hasil dari server:", balikan)

client.close()
# Out:
# [SERVER] Connected by ('127.0.0.1', 50286)
# [SERVER] Received: Tes Koneksi
# Hasil dari server: Tes Koneksi
